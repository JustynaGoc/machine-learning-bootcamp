# %% [markdown]
# <a href="https://colab.research.google.com/github/JustynaGoc/machine-learning-bootcamp/blob/main/Supervised/01_linear_regression_normal_equation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01_linear_regression_normal_equation.ipynb

# %%
import numpy as np

# %%
X1 = np.array([1,2,3,4,5,6])
Y = np.array([3000,3250,3500,3750,4000,4250])
m = len(X1)

# %%
print(f'Lata pracy: {X1}')
print(f'Wynagrodzenie: {Y}')
print(f'Liczba próbek: {m}')
# Out:
# Lata pracy: [1 2 3 4 5 6]
# Wynagrodzenie: [3000 3250 3500 3750 4000 4250]
# Liczba próbek: 6

# %%
X1 = X1.reshape(m,1)
X1.shape
# Out:
# (6, 1)

# %%
bias  = np.ones((m,1))
bias
# Out:
# array([[1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.]])

# %%
X  = np.append(bias, X1, axis=1)
X
# Out:
# array([[1., 1.],
#        [1., 2.],
#        [1., 3.],
#        [1., 4.],
#        [1., 5.],
#        [1., 6.]])

# %%
np.dot(X.T,X)
# Out:
# array([[ 6., 21.],
#        [21., 91.]])

# %%
L = np.linalg.inv(np.dot(X.T,X))
L
# Out:
# array([[ 0.86666667, -0.2       ],
#        [-0.2       ,  0.05714286]])

# %%
P = np.dot(X.T,Y)
P
# Out:
# array([21750., 80500.])

# %%
np.dot(L,P)
# Out:
# array([2750.,  250.])

# %% [markdown]
# # Regresja Liniowa przy pomocy scikit-learn

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()

# %%
regression.fit(X1,Y)
# Out:
# LinearRegression()

# %%
print(regression.coef_[0])
print(regression.intercept_)
# Out:
# 250.0
# 2750.0

# %%
regression.predict([[7]])
# Out:
# array([4500.])
